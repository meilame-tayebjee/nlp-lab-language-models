# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE
counter = collections.Counter(text)
chars = counter.keys()
###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
split = int(0.9*len(data))
train_data = data[:split]
val_data = data[split:]


###

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([231685])
# context is > < target is >i<
# context is > i< target is >l<
# context is > il< target is >l<
# context is > ill< target is >o<
# context is > illo< target is >g<
# context is > illog< target is >i<
# context is > illogi< target is >q<
# context is > illogiq< target is >u<

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
# data loading
def get_batch(split, device = 'cuda'):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(len(data) - block_size, (batch_size,))

    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([data[start:start+block_size] for start in starting_points])
    y = torch.stack([data[start+1:start+1+block_size] for start in starting_points])

    # y is the character after each starting position

    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.embedding = nn.Embedding(vocab_size, vocab_size)

        
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE

        ## 
        logits = self.embedding(idx)
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)

            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

vocab_size = len(chars)
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)
print(vocab_size)
# Out:
# 101

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train', device = device)
logits, loss = m(xb, yb)
print(logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 2.8574647903442383

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))
## YOUR CODE HERE
prompt = torch.tensor(encode(['\n']), dtype=torch.long, device=device).unsqueeze(0)
next_token = m.generate(prompt, 100)
next_words = decode(next_token[0].tolist())
print(next_words)

###
# Out:
# [3]
#
# HHzn«rkÔÊMVhSÂIHX6Âed,,MY5,ïBN, ëa1
# 4léGùSÉ4Nn5QgnXzoElb ëôsoBçn«ûR.
# 2OlnFZ(rçJ[ÉZq[h.CHéda.js85EI_7

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.1436, val loss 5.2408
# step 10: train loss 5.0636, val loss 5.2214
# step 20: train loss 5.1109, val loss 5.2209
# step 30: train loss 5.0469, val loss 5.1692
# step 40: train loss 5.0703, val loss 5.2695
# step 50: train loss 5.0639, val loss 5.2408
# step 60: train loss 5.1804, val loss 5.3269
# step 70: train loss 5.1201, val loss 5.1413
# step 80: train loss 5.0803, val loss 5.2138
# step 90: train loss 5.1578, val loss 5.1986
# step 100: train loss 5.0000, val loss 5.1211
# step 110: train loss 5.0579, val loss 5.1522
# step 120: train loss 4.9591, val loss 5.0819
# step 130: train loss 5.0229, val loss 5.1492
# step 140: train loss 4.9628, val loss 5.1057
# step 150: train loss 4.9574, val loss 5.1295
# step 160: train loss 5.0911, val loss 5.0938
# step 170: train loss 4.9814, val loss 5.0140
# step 180: train loss 4.9736, val loss 5.0861
# step 190: train loss 4.9893, val loss 5.0785
# step 200: train loss 4.9580, val loss 5.0963
# step 210: train loss 4.9817, val loss 5.0701
# step 220: train loss 4.9995, val loss 4.9712
# step 230: train loss 4.9079, val loss 5.0927
# step 240: train loss 4.8951, val loss 5.1055
# step 250: train loss 4.9794, val loss 4.9230
# step 260: train loss 4.9460, val loss 4.9941
# step 270: train loss 4.9718, val loss 5.0182
# step 280: train loss 4.8678, val loss 4.9963
# step 290: train loss 4.9567, val loss 5.0395
# step 300: train loss 4.8867, val loss 5.0089
# step 310: train loss 4.8944, val loss 5.0113
# step 320: train loss 4.8495, val loss 4.9363
# step 330: train loss 4.8733, val loss 5.0106
# step 340: train loss 4.8649, val loss 4.9776
# step 350: train loss 4.8267, val loss 4.9795
# step 360: train loss 4.8236, val loss 5.0120
# step 370: train loss 4.8612, val loss 4.9580
# step 380: train loss 4.7733, val loss 4.9335
# step 390: train loss 4.7835, val loss 4.9338
# step 400: train loss 4.8398, val loss 4.8667
# step 410: train loss 4.7776, val loss 4.8845
# step 420: train loss 4.7701, val loss 4.8480
# step 430: train loss 4.7667, val loss 4.8779
# step 440: train loss 4.7794, val loss 4.8969
# step 450: train loss 4.8402, val loss 4.8927
# step 460: train loss 4.7369, val loss 4.9116
# step 470: train loss 4.7093, val loss 4.9217
# step 480: train loss 4.7600, val loss 4.8801
# step 490: train loss 4.6932, val loss 4.9148
# step 500: train loss 4.8050, val loss 4.8426
# step 510: train loss 4.6722, val loss 4.7999
# step 520: train loss 4.6718, val loss 4.7833
# step 530: train loss 4.7527, val loss 4.7162
# step 540: train loss 4.6673, val loss 4.8145
# step 550: train loss 4.6592, val loss 4.8260
# step 560: train loss 4.6823, val loss 4.7563
# step 570: train loss 4.6379, val loss 4.7548
# step 580: train loss 4.6696, val loss 4.7414
# step 590: train loss 4.5975, val loss 4.8135
# step 600: train loss 4.6916, val loss 4.8176
# step 610: train loss 4.6792, val loss 4.7612
# step 620: train loss 4.5976, val loss 4.7185
# step 630: train loss 4.6462, val loss 4.6967
# step 640: train loss 4.6747, val loss 4.7770
# step 650: train loss 4.5745, val loss 4.7215
# step 660: train loss 4.5693, val loss 4.7631
# step 670: train loss 4.5940, val loss 4.8037
# step 680: train loss 4.5997, val loss 4.6585
# step 690: train loss 4.5699, val loss 4.6706
# step 700: train loss 4.5100, val loss 4.6783
# step 710: train loss 4.5457, val loss 4.6968
# step 720: train loss 4.4937, val loss 4.6465
# step 730: train loss 4.6055, val loss 4.6914
# step 740: train loss 4.5457, val loss 4.5796
# step 750: train loss 4.4855, val loss 4.5707
# step 760: train loss 4.5569, val loss 4.6830
# step 770: train loss 4.5023, val loss 4.5317
# step 780: train loss 4.4345, val loss 4.5851
# step 790: train loss 4.5199, val loss 4.6629
# step 800: train loss 4.5028, val loss 4.6167
# step 810: train loss 4.5166, val loss 4.6121
# step 820: train loss 4.4191, val loss 4.5509
# step 830: train loss 4.5267, val loss 4.5467
# step 840: train loss 4.4495, val loss 4.5718
# step 850: train loss 4.3270, val loss 4.5799
# step 860: train loss 4.4291, val loss 4.4961
# step 870: train loss 4.4118, val loss 4.6326
# step 880: train loss 4.4165, val loss 4.5974
# step 890: train loss 4.3941, val loss 4.4889
# step 900: train loss 4.3804, val loss 4.4962
# step 910: train loss 4.3904, val loss 4.5134
# step 920: train loss 4.4018, val loss 4.5499
# step 930: train loss 4.4116, val loss 4.4726
# step 940: train loss 4.2877, val loss 4.5417
# step 950: train loss 4.3613, val loss 4.4877
# step 960: train loss 4.2871, val loss 4.3674
# step 970: train loss 4.3215, val loss 4.5350
# step 980: train loss 4.3278, val loss 4.4273
# step 990: train loss 4.2635, val loss 4.3588
# step 1000: train loss 4.3165, val loss 4.4776
# step 1010: train loss 4.2870, val loss 4.3864
# step 1020: train loss 4.2747, val loss 4.4811
# step 1030: train loss 4.3070, val loss 4.5010
# step 1040: train loss 4.3453, val loss 4.4749
# step 1050: train loss 4.3414, val loss 4.4902
# step 1060: train loss 4.2989, val loss 4.3226
# step 1070: train loss 4.2677, val loss 4.4229
# step 1080: train loss 4.2542, val loss 4.4394
# step 1090: train loss 4.2876, val loss 4.3508
# step 1100: train loss 4.2398, val loss 4.4420
# step 1110: train loss 4.2760, val loss 4.4565
# step 1120: train loss 4.2424, val loss 4.4426
# step 1130: train loss 4.2513, val loss 4.4055
# step 1140: train loss 4.3239, val loss 4.3113
# step 1150: train loss 4.2184, val loss 4.3541
# step 1160: train loss 4.1826, val loss 4.2824
# step 1170: train loss 4.1957, val loss 4.3709
# step 1180: train loss 4.2553, val loss 4.3989
# step 1190: train loss 4.1613, val loss 4.3543
# step 1200: train loss 4.2324, val loss 4.2685
# step 1210: train loss 4.2437, val loss 4.3519
# step 1220: train loss 4.2454, val loss 4.3219
# step 1230: train loss 4.2349, val loss 4.3203
# step 1240: train loss 4.0813, val loss 4.3741
# step 1250: train loss 4.1397, val loss 4.2432
# step 1260: train loss 4.1929, val loss 4.3100
# step 1270: train loss 4.2098, val loss 4.2466
# step 1280: train loss 4.1595, val loss 4.2613
# step 1290: train loss 4.1122, val loss 4.3161
# step 1300: train loss 4.1059, val loss 4.2391
# step 1310: train loss 4.1035, val loss 4.2616
# step 1320: train loss 4.1099, val loss 4.2569
# step 1330: train loss 4.0928, val loss 4.2544
# step 1340: train loss 4.0456, val loss 4.1863
# step 1350: train loss 4.1177, val loss 4.2703
# step 1360: train loss 4.1541, val loss 4.2008
# step 1370: train loss 4.1039, val loss 4.1794
# step 1380: train loss 4.1204, val loss 4.2536
# step 1390: train loss 4.0725, val loss 4.1224
# step 1400: train loss 4.0607, val loss 4.2527
# step 1410: train loss 4.0099, val loss 4.1808
# step 1420: train loss 4.1154, val loss 4.2049
# step 1430: train loss 4.0648, val loss 4.1259
# step 1440: train loss 4.0640, val loss 4.1831
# step 1450: train loss 4.0301, val loss 4.0995
# step 1460: train loss 4.0740, val loss 4.1333
# step 1470: train loss 3.9906, val loss 4.1947
# step 1480: train loss 3.9613, val loss 4.2969
# step 1490: train loss 4.0582, val loss 4.1517
# step 1500: train loss 4.0815, val loss 4.1774
# step 1510: train loss 3.9488, val loss 4.0915
# step 1520: train loss 3.9853, val loss 4.1453
# step 1530: train loss 4.1208, val loss 4.1199
# step 1540: train loss 3.9126, val loss 4.0813
# step 1550: train loss 3.9078, val loss 4.0682
# step 1560: train loss 3.9666, val loss 4.2122
# step 1570: train loss 4.0186, val loss 4.0188
# step 1580: train loss 4.0244, val loss 4.2081
# step 1590: train loss 3.9285, val loss 4.0508
# step 1600: train loss 3.9353, val loss 4.0704
# step 1610: train loss 3.9019, val loss 4.0447
# step 1620: train loss 3.8976, val loss 4.0463
# step 1630: train loss 3.8890, val loss 4.1141
# step 1640: train loss 3.8843, val loss 4.0398
# step 1650: train loss 3.9184, val loss 4.0282
# step 1660: train loss 3.8612, val loss 4.0830
# step 1670: train loss 3.9113, val loss 4.0569
# step 1680: train loss 3.8863, val loss 3.9754
# step 1690: train loss 3.8574, val loss 4.1082
# step 1700: train loss 3.8861, val loss 4.1027
# step 1710: train loss 3.8990, val loss 4.0376
# step 1720: train loss 3.8518, val loss 3.9395
# step 1730: train loss 3.8278, val loss 3.8907
# step 1740: train loss 3.8429, val loss 4.0765
# step 1750: train loss 3.9286, val loss 4.1525
# step 1760: train loss 3.8670, val loss 3.9907
# step 1770: train loss 3.7905, val loss 3.9798
# step 1780: train loss 3.7588, val loss 4.0058
# step 1790: train loss 3.8279, val loss 3.9482
# step 1800: train loss 3.9030, val loss 3.9444
# step 1810: train loss 3.8286, val loss 3.9888
# step 1820: train loss 3.8936, val loss 4.0275
# step 1830: train loss 3.7970, val loss 4.0109
# step 1840: train loss 3.8059, val loss 3.9662
# step 1850: train loss 3.8702, val loss 3.9469
# step 1860: train loss 3.8487, val loss 3.9720
# step 1870: train loss 3.7984, val loss 3.9929
# step 1880: train loss 3.7711, val loss 3.9531
# step 1890: train loss 3.8786, val loss 3.8921
# step 1900: train loss 3.8166, val loss 3.8822
# step 1910: train loss 3.7708, val loss 3.8857
# step 1920: train loss 3.7963, val loss 3.9161
# step 1930: train loss 3.7343, val loss 3.9423
# step 1940: train loss 3.7594, val loss 3.9733
# step 1950: train loss 3.7365, val loss 3.8472
# step 1960: train loss 3.7039, val loss 3.8794
# step 1970: train loss 3.7152, val loss 3.8619
# step 1980: train loss 3.7623, val loss 3.8882
# step 1990: train loss 3.7460, val loss 3.9091
# step 2000: train loss 3.7462, val loss 3.8148
# step 2010: train loss 3.8002, val loss 3.8638
# step 2020: train loss 3.7065, val loss 3.8527
# step 2030: train loss 3.7424, val loss 3.9249
# step 2040: train loss 3.7246, val loss 3.8044
# step 2050: train loss 3.6806, val loss 3.9477
# step 2060: train loss 3.7672, val loss 3.8847
# step 2070: train loss 3.7242, val loss 3.8396
# step 2080: train loss 3.7278, val loss 3.9651
# step 2090: train loss 3.7202, val loss 3.8520
# step 2100: train loss 3.6665, val loss 3.9216
# step 2110: train loss 3.6791, val loss 3.8081
# step 2120: train loss 3.5807, val loss 3.8453
# step 2130: train loss 3.6731, val loss 3.7209
# step 2140: train loss 3.6627, val loss 3.8396
# step 2150: train loss 3.6856, val loss 3.8074
# step 2160: train loss 3.5840, val loss 3.7856
# step 2170: train loss 3.7129, val loss 3.8750
# step 2180: train loss 3.6437, val loss 3.7335
# step 2190: train loss 3.6854, val loss 3.8037
# step 2200: train loss 3.6113, val loss 3.8139
# step 2210: train loss 3.6465, val loss 3.7654
# step 2220: train loss 3.5699, val loss 3.6792
# step 2230: train loss 3.6519, val loss 3.8382
# step 2240: train loss 3.6849, val loss 3.6542
# step 2250: train loss 3.6237, val loss 3.6897
# step 2260: train loss 3.6370, val loss 3.8821
# step 2270: train loss 3.6771, val loss 3.7285
# step 2280: train loss 3.6347, val loss 3.7381
# step 2290: train loss 3.6204, val loss 3.7119
# step 2300: train loss 3.6334, val loss 3.7000
# step 2310: train loss 3.6821, val loss 3.6989
# step 2320: train loss 3.5737, val loss 3.7215
# step 2330: train loss 3.6010, val loss 3.7262
# step 2340: train loss 3.6037, val loss 3.6800
# step 2350: train loss 3.5554, val loss 3.7542
# step 2360: train loss 3.5010, val loss 3.7124
# step 2370: train loss 3.5294, val loss 3.7616
# step 2380: train loss 3.5593, val loss 3.6682
# step 2390: train loss 3.5441, val loss 3.7204
# step 2400: train loss 3.5869, val loss 3.7286
# step 2410: train loss 3.5591, val loss 3.7780
# step 2420: train loss 3.5959, val loss 3.7347
# step 2430: train loss 3.5278, val loss 3.7188
# step 2440: train loss 3.5307, val loss 3.6714
# step 2450: train loss 3.4976, val loss 3.6273
# step 2460: train loss 3.6247, val loss 3.6934
# step 2470: train loss 3.5037, val loss 3.7399
# step 2480: train loss 3.5249, val loss 3.7294
# step 2490: train loss 3.4963, val loss 3.6250
# step 2500: train loss 3.5621, val loss 3.6672
# step 2510: train loss 3.5011, val loss 3.6462
# step 2520: train loss 3.4610, val loss 3.7486
# step 2530: train loss 3.4927, val loss 3.5634
# step 2540: train loss 3.5847, val loss 3.6021
# step 2550: train loss 3.4472, val loss 3.6759
# step 2560: train loss 3.4490, val loss 3.6258
# step 2570: train loss 3.5111, val loss 3.6718
# step 2580: train loss 3.4764, val loss 3.5680
# step 2590: train loss 3.4657, val loss 3.5732
# step 2600: train loss 3.5056, val loss 3.5631
# step 2610: train loss 3.4507, val loss 3.5980
# step 2620: train loss 3.4520, val loss 3.6205
# step 2630: train loss 3.4393, val loss 3.5939
# step 2640: train loss 3.4259, val loss 3.7087
# step 2650: train loss 3.5066, val loss 3.6990
# step 2660: train loss 3.4859, val loss 3.5832
# step 2670: train loss 3.5005, val loss 3.6523
# step 2680: train loss 3.4564, val loss 3.4992
# step 2690: train loss 3.3778, val loss 3.5794
# step 2700: train loss 3.3530, val loss 3.5934
# step 2710: train loss 3.4612, val loss 3.5673
# step 2720: train loss 3.3407, val loss 3.5745
# step 2730: train loss 3.3714, val loss 3.6299
# step 2740: train loss 3.4038, val loss 3.4740
# step 2750: train loss 3.4268, val loss 3.5299
# step 2760: train loss 3.4912, val loss 3.5820
# step 2770: train loss 3.4300, val loss 3.6035
# step 2780: train loss 3.4593, val loss 3.5725
# step 2790: train loss 3.3137, val loss 3.6123
# step 2800: train loss 3.3692, val loss 3.4391
# step 2810: train loss 3.4436, val loss 3.6566
# step 2820: train loss 3.3555, val loss 3.5400
# step 2830: train loss 3.3896, val loss 3.6356
# step 2840: train loss 3.4210, val loss 3.5099
# step 2850: train loss 3.4123, val loss 3.5264
# step 2860: train loss 3.3722, val loss 3.4812
# step 2870: train loss 3.3281, val loss 3.4666
# step 2880: train loss 3.3497, val loss 3.4853
# step 2890: train loss 3.3361, val loss 3.4528
# step 2900: train loss 3.3424, val loss 3.6041
# step 2910: train loss 3.3325, val loss 3.5221
# step 2920: train loss 3.4427, val loss 3.4730
# step 2930: train loss 3.3573, val loss 3.5951
# step 2940: train loss 3.4119, val loss 3.4406
# step 2950: train loss 3.3066, val loss 3.3905
# step 2960: train loss 3.3131, val loss 3.4156
# step 2970: train loss 3.3169, val loss 3.4584
# step 2980: train loss 3.2544, val loss 3.4412
# step 2990: train loss 3.2337, val loss 3.4976
# step 3000: train loss 3.3958, val loss 3.5429
# step 3010: train loss 3.3273, val loss 3.4997
# step 3020: train loss 3.2826, val loss 3.4280
# step 3030: train loss 3.2940, val loss 3.4898
# step 3040: train loss 3.3246, val loss 3.4459
# step 3050: train loss 3.3329, val loss 3.5463
# step 3060: train loss 3.3785, val loss 3.4754
# step 3070: train loss 3.3325, val loss 3.5082
# step 3080: train loss 3.3092, val loss 3.4112
# step 3090: train loss 3.2565, val loss 3.4915
# step 3100: train loss 3.2294, val loss 3.4291
# step 3110: train loss 3.2693, val loss 3.4640
# step 3120: train loss 3.3482, val loss 3.4641
# step 3130: train loss 3.2731, val loss 3.4446
# step 3140: train loss 3.3020, val loss 3.3282
# step 3150: train loss 3.1896, val loss 3.4022
# step 3160: train loss 3.2113, val loss 3.4541
# step 3170: train loss 3.2202, val loss 3.3692
# step 3180: train loss 3.2626, val loss 3.4046
# step 3190: train loss 3.2365, val loss 3.4748
# step 3200: train loss 3.2535, val loss 3.3876
# step 3210: train loss 3.2084, val loss 3.3028
# step 3220: train loss 3.2817, val loss 3.4716
# step 3230: train loss 3.2555, val loss 3.4762
# step 3240: train loss 3.1974, val loss 3.3527
# step 3250: train loss 3.2332, val loss 3.4083
# step 3260: train loss 3.2344, val loss 3.3275
# step 3270: train loss 3.2797, val loss 3.3757
# step 3280: train loss 3.2059, val loss 3.3027
# step 3290: train loss 3.3102, val loss 3.3906
# step 3300: train loss 3.2989, val loss 3.3277
# step 3310: train loss 3.2526, val loss 3.3287
# step 3320: train loss 3.2330, val loss 3.4419
# step 3330: train loss 3.2293, val loss 3.4151
# step 3340: train loss 3.2534, val loss 3.3234
# step 3350: train loss 3.1968, val loss 3.3103
# step 3360: train loss 3.1714, val loss 3.3375
# step 3370: train loss 3.2219, val loss 3.3826
# step 3380: train loss 3.2091, val loss 3.3767
# step 3390: train loss 3.2166, val loss 3.4794
# step 3400: train loss 3.2730, val loss 3.4302
# step 3410: train loss 3.1851, val loss 3.3629
# step 3420: train loss 3.2064, val loss 3.3721
# step 3430: train loss 3.1560, val loss 3.3047
# step 3440: train loss 3.1394, val loss 3.3678
# step 3450: train loss 3.2698, val loss 3.3209
# step 3460: train loss 3.1291, val loss 3.4795
# step 3470: train loss 3.1664, val loss 3.3439
# step 3480: train loss 3.1727, val loss 3.1920
# step 3490: train loss 3.2313, val loss 3.2926
# step 3500: train loss 3.1577, val loss 3.3050
# step 3510: train loss 3.1337, val loss 3.2428
# step 3520: train loss 3.1041, val loss 3.4245
# step 3530: train loss 3.1048, val loss 3.2352
# step 3540: train loss 3.1670, val loss 3.2967
# step 3550: train loss 3.1840, val loss 3.3740
# step 3560: train loss 3.1679, val loss 3.2394
# step 3570: train loss 3.0936, val loss 3.2801
# step 3580: train loss 3.1246, val loss 3.3197
# step 3590: train loss 3.1457, val loss 3.1901
# step 3600: train loss 3.1375, val loss 3.2226
# step 3610: train loss 3.1266, val loss 3.3536
# step 3620: train loss 3.1942, val loss 3.3603
# step 3630: train loss 3.0833, val loss 3.2602
# step 3640: train loss 3.1160, val loss 3.2619
# step 3650: train loss 3.1877, val loss 3.2939
# step 3660: train loss 3.1533, val loss 3.3508
# step 3670: train loss 3.1262, val loss 3.2802
# step 3680: train loss 3.1141, val loss 3.2569
# step 3690: train loss 2.9912, val loss 3.3448
# step 3700: train loss 3.0296, val loss 3.3114
# step 3710: train loss 3.0999, val loss 3.2340
# step 3720: train loss 3.1475, val loss 3.4164
# step 3730: train loss 3.1342, val loss 3.2447
# step 3740: train loss 3.1203, val loss 3.4272
# step 3750: train loss 3.0438, val loss 3.1778
# step 3760: train loss 3.0490, val loss 3.1891
# step 3770: train loss 3.1484, val loss 3.2626
# step 3780: train loss 3.1929, val loss 3.3113
# step 3790: train loss 3.0784, val loss 3.2851
# step 3800: train loss 3.0803, val loss 3.2187
# step 3810: train loss 3.1004, val loss 3.3335
# step 3820: train loss 3.0207, val loss 3.3399
# step 3830: train loss 3.0789, val loss 3.2375
# step 3840: train loss 3.0825, val loss 3.3367
# step 3850: train loss 3.1169, val loss 3.2065
# step 3860: train loss 3.0297, val loss 3.2177
# step 3870: train loss 3.0248, val loss 3.1978
# step 3880: train loss 3.1163, val loss 3.1005
# step 3890: train loss 3.1022, val loss 3.1981
# step 3900: train loss 3.0564, val loss 3.1895
# step 3910: train loss 3.0827, val loss 3.2502
# step 3920: train loss 3.1125, val loss 3.3625
# step 3930: train loss 3.0238, val loss 3.1943
# step 3940: train loss 3.0281, val loss 3.1971
# step 3950: train loss 3.0406, val loss 3.2582
# step 3960: train loss 3.0914, val loss 3.3346
# step 3970: train loss 3.0489, val loss 3.1547
# step 3980: train loss 3.1142, val loss 3.2262
# step 3990: train loss 3.0900, val loss 3.2440
# step 4000: train loss 2.9941, val loss 3.1185
# step 4010: train loss 3.0463, val loss 3.2531
# step 4020: train loss 3.0421, val loss 3.1930
# step 4030: train loss 2.9675, val loss 3.1996
# step 4040: train loss 3.0654, val loss 3.1119
# step 4050: train loss 3.0000, val loss 3.2475
# step 4060: train loss 3.0227, val loss 3.2155
# step 4070: train loss 3.0482, val loss 3.2217
# step 4080: train loss 3.0065, val loss 3.1458
# step 4090: train loss 3.1177, val loss 3.2057
# step 4100: train loss 2.9566, val loss 3.3279
# step 4110: train loss 2.9880, val loss 3.2314
# step 4120: train loss 3.0409, val loss 3.0745
# step 4130: train loss 3.0677, val loss 3.1845
# step 4140: train loss 2.9819, val loss 3.2243
# step 4150: train loss 3.0397, val loss 3.2429
# step 4160: train loss 2.9878, val loss 3.2312
# step 4170: train loss 2.9898, val loss 3.2049
# step 4180: train loss 3.0257, val loss 3.2531
# step 4190: train loss 2.9884, val loss 3.1625
# step 4200: train loss 2.9994, val loss 3.0715
# step 4210: train loss 2.9598, val loss 3.1925
# step 4220: train loss 3.0136, val loss 3.2466
# step 4230: train loss 3.0635, val loss 3.2228
# step 4240: train loss 2.9916, val loss 3.1778
# step 4250: train loss 3.0304, val loss 3.0808
# step 4260: train loss 2.9165, val loss 3.0523
# step 4270: train loss 2.9726, val loss 3.2549
# step 4280: train loss 2.9187, val loss 3.0725
# step 4290: train loss 2.9733, val loss 3.2097
# step 4300: train loss 2.9308, val loss 3.1520
# step 4310: train loss 2.9005, val loss 3.0316
# step 4320: train loss 2.8783, val loss 3.1229
# step 4330: train loss 2.9493, val loss 3.1387
# step 4340: train loss 2.9339, val loss 3.1400
# step 4350: train loss 2.9730, val loss 3.2067
# step 4360: train loss 2.9824, val loss 3.1975
# step 4370: train loss 2.9601, val loss 3.0214
# step 4380: train loss 2.8837, val loss 3.1174
# step 4390: train loss 2.9898, val loss 3.1468
# step 4400: train loss 2.9317, val loss 3.1426
# step 4410: train loss 2.9992, val loss 3.1500
# step 4420: train loss 2.9169, val loss 3.2018
# step 4430: train loss 2.9137, val loss 3.1244
# step 4440: train loss 2.8794, val loss 3.2140
# step 4450: train loss 2.9720, val loss 3.2116
# step 4460: train loss 2.9363, val loss 3.1790
# step 4470: train loss 2.9904, val loss 3.2751
# step 4480: train loss 2.8805, val loss 2.9485
# step 4490: train loss 2.9997, val loss 3.1217
# step 4500: train loss 2.9714, val loss 3.2553
# step 4510: train loss 2.9328, val loss 3.2269
# step 4520: train loss 2.8880, val loss 2.9604
# step 4530: train loss 3.0125, val loss 3.1552
# step 4540: train loss 2.9132, val loss 2.9954
# step 4550: train loss 2.8904, val loss 3.2001
# step 4560: train loss 2.8808, val loss 3.1050
# step 4570: train loss 2.9147, val loss 3.0384
# step 4580: train loss 2.9137, val loss 3.0075
# step 4590: train loss 2.8828, val loss 3.1022
# step 4600: train loss 2.7937, val loss 3.0863
# step 4610: train loss 2.8984, val loss 3.1942
# step 4620: train loss 2.9084, val loss 3.0603
# step 4630: train loss 2.9451, val loss 3.1639
# step 4640: train loss 2.9153, val loss 3.0546
# step 4650: train loss 2.9835, val loss 2.9960
# step 4660: train loss 2.8397, val loss 2.9084
# step 4670: train loss 2.8463, val loss 2.8886
# step 4680: train loss 2.8724, val loss 3.1477
# step 4690: train loss 2.9378, val loss 3.1464
# step 4700: train loss 2.8596, val loss 3.1009
# step 4710: train loss 2.9235, val loss 2.9457
# step 4720: train loss 2.8601, val loss 3.1375
# step 4730: train loss 2.7785, val loss 3.0541
# step 4740: train loss 2.7701, val loss 3.0570
# step 4750: train loss 2.8145, val loss 3.0081
# step 4760: train loss 2.8596, val loss 3.2444
# step 4770: train loss 2.8900, val loss 3.0218
# step 4780: train loss 2.9206, val loss 3.0333
# step 4790: train loss 2.8746, val loss 2.9991
# step 4800: train loss 2.8905, val loss 3.0741
# step 4810: train loss 2.8772, val loss 3.0540
# step 4820: train loss 2.8817, val loss 3.0435
# step 4830: train loss 2.8340, val loss 3.0561
# step 4840: train loss 2.9370, val loss 2.9364
# step 4850: train loss 2.9094, val loss 3.0822
# step 4860: train loss 2.9163, val loss 3.0100
# step 4870: train loss 2.8412, val loss 3.0619
# step 4880: train loss 2.8260, val loss 3.0021
# step 4890: train loss 2.8504, val loss 2.9693
# step 4900: train loss 2.7639, val loss 3.0489
# step 4910: train loss 2.8846, val loss 3.1441
# step 4920: train loss 2.9394, val loss 2.9733
# step 4930: train loss 2.8498, val loss 3.1172
# step 4940: train loss 2.8749, val loss 2.9354
# step 4950: train loss 2.8061, val loss 2.9929
# step 4960: train loss 2.8312, val loss 2.9976
# step 4970: train loss 2.8354, val loss 2.8657
# step 4980: train loss 2.9081, val loss 2.9435
# step 4990: train loss 2.8336, val loss 2.9858
# step 5000: train loss 2.8693, val loss 2.9611
# step 5010: train loss 2.7636, val loss 3.0859
# step 5020: train loss 2.7840, val loss 3.0016
# step 5030: train loss 2.7788, val loss 2.9517
# step 5040: train loss 2.8427, val loss 3.1238
# step 5050: train loss 2.8415, val loss 3.0915
# step 5060: train loss 2.9385, val loss 2.9629
# step 5070: train loss 2.8167, val loss 2.9976
# step 5080: train loss 2.7504, val loss 2.9500
# step 5090: train loss 2.7988, val loss 2.9315
# step 5100: train loss 2.8648, val loss 3.0343
# step 5110: train loss 2.8593, val loss 2.9833
# step 5120: train loss 2.7723, val loss 2.9858
# step 5130: train loss 2.9107, val loss 3.0137
# step 5140: train loss 2.8250, val loss 2.9153
# step 5150: train loss 2.8168, val loss 3.0639
# step 5160: train loss 2.8294, val loss 2.9644
# step 5170: train loss 2.8502, val loss 2.9823
# step 5180: train loss 2.8616, val loss 2.9863
# step 5190: train loss 2.8569, val loss 2.9639
# step 5200: train loss 2.8366, val loss 3.0284
# step 5210: train loss 2.8241, val loss 3.0349
# step 5220: train loss 2.7994, val loss 2.9651
# step 5230: train loss 2.8314, val loss 2.9246
# step 5240: train loss 2.8434, val loss 2.9071
# step 5250: train loss 2.7736, val loss 3.0265
# step 5260: train loss 2.8974, val loss 2.9940
# step 5270: train loss 2.8569, val loss 2.9079
# step 5280: train loss 2.7847, val loss 2.9668
# step 5290: train loss 2.8061, val loss 2.9186
# step 5300: train loss 2.7698, val loss 3.0747
# step 5310: train loss 2.8568, val loss 2.9925
# step 5320: train loss 2.7459, val loss 3.0274
# step 5330: train loss 2.7868, val loss 3.0016
# step 5340: train loss 2.7650, val loss 2.9172
# step 5350: train loss 2.8418, val loss 3.0530
# step 5360: train loss 2.8122, val loss 2.9248
# step 5370: train loss 2.8253, val loss 3.0579
# step 5380: train loss 2.8364, val loss 3.0557
# step 5390: train loss 2.7681, val loss 2.9647
# step 5400: train loss 2.7673, val loss 3.0456
# step 5410: train loss 2.8484, val loss 2.8499
# step 5420: train loss 2.8038, val loss 2.9327
# step 5430: train loss 2.8823, val loss 3.0631
# step 5440: train loss 2.7669, val loss 2.9085
# step 5450: train loss 2.7440, val loss 2.9334
# step 5460: train loss 2.7830, val loss 2.9662
# step 5470: train loss 2.7965, val loss 2.9244
# step 5480: train loss 2.8783, val loss 2.9510
# step 5490: train loss 2.8444, val loss 2.9165
# step 5500: train loss 2.7197, val loss 2.8871
# step 5510: train loss 2.7134, val loss 2.8943
# step 5520: train loss 2.7970, val loss 2.9089
# step 5530: train loss 2.7445, val loss 2.9784
# step 5540: train loss 2.8408, val loss 2.8454
# step 5550: train loss 2.8306, val loss 2.8682
# step 5560: train loss 2.8137, val loss 2.8994
# step 5570: train loss 2.8377, val loss 3.1146
# step 5580: train loss 2.8243, val loss 3.0128
# step 5590: train loss 2.8367, val loss 3.0002
# step 5600: train loss 2.8369, val loss 2.8546
# step 5610: train loss 2.9014, val loss 2.9385
# step 5620: train loss 2.7708, val loss 2.9613
# step 5630: train loss 2.8368, val loss 2.8642
# step 5640: train loss 2.8133, val loss 2.9807
# step 5650: train loss 2.7263, val loss 2.9447
# step 5660: train loss 2.7337, val loss 2.8475
# step 5670: train loss 2.7822, val loss 2.8166
# step 5680: train loss 2.7804, val loss 3.0481
# step 5690: train loss 2.7431, val loss 2.8434
# step 5700: train loss 2.7196, val loss 2.9992
# step 5710: train loss 2.8303, val loss 2.8939
# step 5720: train loss 2.7588, val loss 2.9407
# step 5730: train loss 2.7294, val loss 2.9636
# step 5740: train loss 2.7668, val loss 2.9694
# step 5750: train loss 2.8193, val loss 2.8231
# step 5760: train loss 2.7541, val loss 2.8875
# step 5770: train loss 2.7037, val loss 2.9249
# step 5780: train loss 2.7194, val loss 2.9245
# step 5790: train loss 2.7257, val loss 3.0495
# step 5800: train loss 2.7606, val loss 2.9652
# step 5810: train loss 2.7729, val loss 3.0819
# step 5820: train loss 2.8125, val loss 3.0062
# step 5830: train loss 2.7147, val loss 2.8235
# step 5840: train loss 2.7286, val loss 2.8299
# step 5850: train loss 2.7342, val loss 2.8333
# step 5860: train loss 2.8590, val loss 2.8747
# step 5870: train loss 2.7976, val loss 2.7922
# step 5880: train loss 2.7711, val loss 2.9109
# step 5890: train loss 2.7210, val loss 2.8365
# step 5900: train loss 2.7024, val loss 2.8699
# step 5910: train loss 2.7477, val loss 2.9172
# step 5920: train loss 2.6922, val loss 2.8029
# step 5930: train loss 2.7639, val loss 2.9472
# step 5940: train loss 2.7407, val loss 2.8953
# step 5950: train loss 2.6475, val loss 2.8193
# step 5960: train loss 2.7272, val loss 2.8161
# step 5970: train loss 2.7083, val loss 2.7893
# step 5980: train loss 2.7187, val loss 2.8557
# step 5990: train loss 2.7170, val loss 2.9333
# step 6000: train loss 2.7576, val loss 2.8369
# step 6010: train loss 2.7531, val loss 2.9820
# step 6020: train loss 2.6769, val loss 2.8526
# step 6030: train loss 2.6960, val loss 2.9115
# step 6040: train loss 2.6978, val loss 2.9508
# step 6050: train loss 2.7254, val loss 2.7809
# step 6060: train loss 2.7544, val loss 2.7570
# step 6070: train loss 2.7523, val loss 2.6905
# step 6080: train loss 2.8078, val loss 3.0464
# step 6090: train loss 2.7153, val loss 2.8497
# step 6100: train loss 2.7975, val loss 2.9043
# step 6110: train loss 2.6651, val loss 2.8427
# step 6120: train loss 2.7307, val loss 2.8717
# step 6130: train loss 2.7199, val loss 2.8803
# step 6140: train loss 2.7771, val loss 2.8506
# step 6150: train loss 2.6146, val loss 2.8344
# step 6160: train loss 2.7530, val loss 2.8752
# step 6170: train loss 2.6302, val loss 2.8557
# step 6180: train loss 2.7333, val loss 2.8720
# step 6190: train loss 2.6757, val loss 2.8484
# step 6200: train loss 2.7011, val loss 2.8674
# step 6210: train loss 2.7430, val loss 2.9494
# step 6220: train loss 2.7178, val loss 2.8186
# step 6230: train loss 2.6918, val loss 2.8507
# step 6240: train loss 2.6964, val loss 2.9403
# step 6250: train loss 2.6230, val loss 2.8234
# step 6260: train loss 2.6400, val loss 2.9164
# step 6270: train loss 2.6703, val loss 2.9562
# step 6280: train loss 2.6391, val loss 2.7367
# step 6290: train loss 2.6760, val loss 2.9674
# step 6300: train loss 2.6648, val loss 2.8719
# step 6310: train loss 2.7430, val loss 2.8348
# step 6320: train loss 2.6661, val loss 2.8604
# step 6330: train loss 2.8109, val loss 2.8460
# step 6340: train loss 2.6347, val loss 2.7940
# step 6350: train loss 2.7120, val loss 2.8883
# step 6360: train loss 2.7114, val loss 2.8064
# step 6370: train loss 2.6919, val loss 2.8513
# step 6380: train loss 2.6537, val loss 2.8388
# step 6390: train loss 2.5778, val loss 2.7583
# step 6400: train loss 2.6708, val loss 2.7874
# step 6410: train loss 2.6421, val loss 2.8583
# step 6420: train loss 2.6584, val loss 2.9623
# step 6430: train loss 2.7361, val loss 2.8598
# step 6440: train loss 2.6297, val loss 2.8847
# step 6450: train loss 2.6243, val loss 2.8933
# step 6460: train loss 2.6626, val loss 2.8608
# step 6470: train loss 2.7158, val loss 2.8485
# step 6480: train loss 2.6962, val loss 2.9149
# step 6490: train loss 2.6588, val loss 2.8985
# step 6500: train loss 2.6866, val loss 2.8392
# step 6510: train loss 2.6564, val loss 2.7287
# step 6520: train loss 2.7053, val loss 2.8329
# step 6530: train loss 2.6441, val loss 2.8225
# step 6540: train loss 2.6428, val loss 2.9389
# step 6550: train loss 2.7328, val loss 2.7125
# step 6560: train loss 2.7285, val loss 3.0169
# step 6570: train loss 2.5888, val loss 2.7096
# step 6580: train loss 2.5943, val loss 2.9477
# step 6590: train loss 2.7606, val loss 2.7163
# step 6600: train loss 2.6443, val loss 2.8954
# step 6610: train loss 2.6922, val loss 2.9554
# step 6620: train loss 2.7404, val loss 2.7312
# step 6630: train loss 2.6099, val loss 2.8507
# step 6640: train loss 2.7402, val loss 2.6535
# step 6650: train loss 2.7077, val loss 2.7802
# step 6660: train loss 2.7169, val loss 2.7326
# step 6670: train loss 2.6519, val loss 2.7549
# step 6680: train loss 2.7140, val loss 2.7059
# step 6690: train loss 2.6514, val loss 2.7809
# step 6700: train loss 2.5723, val loss 2.8478
# step 6710: train loss 2.6177, val loss 2.6704
# step 6720: train loss 2.7535, val loss 2.8041
# step 6730: train loss 2.7127, val loss 2.8670
# step 6740: train loss 2.6280, val loss 2.7299
# step 6750: train loss 2.7121, val loss 2.6568
# step 6760: train loss 2.6294, val loss 2.8725
# step 6770: train loss 2.6736, val loss 2.7756
# step 6780: train loss 2.7263, val loss 2.7811
# step 6790: train loss 2.6612, val loss 2.7725
# step 6800: train loss 2.6532, val loss 2.7561
# step 6810: train loss 2.6560, val loss 2.8077
# step 6820: train loss 2.6247, val loss 2.7851
# step 6830: train loss 2.7162, val loss 2.7544
# step 6840: train loss 2.6106, val loss 2.8224
# step 6850: train loss 2.6706, val loss 2.7080
# step 6860: train loss 2.6646, val loss 2.7554
# step 6870: train loss 2.6221, val loss 2.7858
# step 6880: train loss 2.6828, val loss 2.8096
# step 6890: train loss 2.5885, val loss 2.7545
# step 6900: train loss 2.6564, val loss 2.8253
# step 6910: train loss 2.6447, val loss 2.7274
# step 6920: train loss 2.7684, val loss 2.7422
# step 6930: train loss 2.6450, val loss 2.8548
# step 6940: train loss 2.7010, val loss 2.7851
# step 6950: train loss 2.6385, val loss 2.8447
# step 6960: train loss 2.5490, val loss 2.6971
# step 6970: train loss 2.6607, val loss 2.7535
# step 6980: train loss 2.6570, val loss 2.7436
# step 6990: train loss 2.6100, val loss 2.7599
# step 7000: train loss 2.6820, val loss 2.8294
# step 7010: train loss 2.6139, val loss 2.7515
# step 7020: train loss 2.6304, val loss 2.8043
# step 7030: train loss 2.7011, val loss 2.7631
# step 7040: train loss 2.5705, val loss 2.7830
# step 7050: train loss 2.5985, val loss 2.9278
# step 7060: train loss 2.5781, val loss 2.6852
# step 7070: train loss 2.6830, val loss 2.6767
# step 7080: train loss 2.6755, val loss 2.7708
# step 7090: train loss 2.6102, val loss 2.7020
# step 7100: train loss 2.6252, val loss 2.7160
# step 7110: train loss 2.6286, val loss 2.7820
# step 7120: train loss 2.7830, val loss 2.8526
# step 7130: train loss 2.5878, val loss 2.7326
# step 7140: train loss 2.6002, val loss 2.8352
# step 7150: train loss 2.6057, val loss 2.6760
# step 7160: train loss 2.6766, val loss 2.7240
# step 7170: train loss 2.6226, val loss 2.7754
# step 7180: train loss 2.6717, val loss 2.9179
# step 7190: train loss 2.5059, val loss 2.7971
# step 7200: train loss 2.6310, val loss 2.7487
# step 7210: train loss 2.6744, val loss 2.6720
# step 7220: train loss 2.6411, val loss 2.6746
# step 7230: train loss 2.6160, val loss 2.7735
# step 7240: train loss 2.5972, val loss 2.6641
# step 7250: train loss 2.6172, val loss 2.8186
# step 7260: train loss 2.6473, val loss 2.7412
# step 7270: train loss 2.7045, val loss 2.8727
# step 7280: train loss 2.6117, val loss 2.8447
# step 7290: train loss 2.6443, val loss 2.7326
# step 7300: train loss 2.5073, val loss 2.6948
# step 7310: train loss 2.5761, val loss 2.8393
# step 7320: train loss 2.6240, val loss 2.6918
# step 7330: train loss 2.6590, val loss 2.7619
# step 7340: train loss 2.6370, val loss 2.7032
# step 7350: train loss 2.6147, val loss 2.7838
# step 7360: train loss 2.6782, val loss 2.7023
# step 7370: train loss 2.6491, val loss 2.6921
# step 7380: train loss 2.6387, val loss 2.8101
# step 7390: train loss 2.7150, val loss 2.7738
# step 7400: train loss 2.6705, val loss 2.7869
# step 7410: train loss 2.6138, val loss 2.6989
# step 7420: train loss 2.6204, val loss 2.7961
# step 7430: train loss 2.6821, val loss 2.7041
# step 7440: train loss 2.6073, val loss 2.7087
# step 7450: train loss 2.6095, val loss 2.7936
# step 7460: train loss 2.6480, val loss 2.7529
# step 7470: train loss 2.6393, val loss 2.8283
# step 7480: train loss 2.7112, val loss 2.7184
# step 7490: train loss 2.5921, val loss 2.6552
# step 7500: train loss 2.6301, val loss 2.7178
# step 7510: train loss 2.5805, val loss 2.7259
# step 7520: train loss 2.6834, val loss 2.7616
# step 7530: train loss 2.5972, val loss 2.6623
# step 7540: train loss 2.5967, val loss 2.6563
# step 7550: train loss 2.5620, val loss 2.8343
# step 7560: train loss 2.6688, val loss 2.7560
# step 7570: train loss 2.6290, val loss 2.5972
# step 7580: train loss 2.6366, val loss 2.8158
# step 7590: train loss 2.5780, val loss 2.7431
# step 7600: train loss 2.6315, val loss 2.6502
# step 7610: train loss 2.5557, val loss 2.8541
# step 7620: train loss 2.5963, val loss 2.6845
# step 7630: train loss 2.5190, val loss 2.7581
# step 7640: train loss 2.5899, val loss 2.7470
# step 7650: train loss 2.6203, val loss 2.7293
# step 7660: train loss 2.6210, val loss 2.6874
# step 7670: train loss 2.6031, val loss 2.8209
# step 7680: train loss 2.6029, val loss 2.7394
# step 7690: train loss 2.6325, val loss 2.8769
# step 7700: train loss 2.5900, val loss 2.7077
# step 7710: train loss 2.6627, val loss 2.5415
# step 7720: train loss 2.5327, val loss 2.6309
# step 7730: train loss 2.6189, val loss 2.7605
# step 7740: train loss 2.5421, val loss 2.8534
# step 7750: train loss 2.6353, val loss 2.8347
# step 7760: train loss 2.6049, val loss 2.7070
# step 7770: train loss 2.5758, val loss 2.6460
# step 7780: train loss 2.5751, val loss 2.7185
# step 7790: train loss 2.6241, val loss 2.6707
# step 7800: train loss 2.6552, val loss 2.7630
# step 7810: train loss 2.5771, val loss 2.6592
# step 7820: train loss 2.5337, val loss 2.6719
# step 7830: train loss 2.6325, val loss 2.7170
# step 7840: train loss 2.5742, val loss 2.7325
# step 7850: train loss 2.5862, val loss 2.7888
# step 7860: train loss 2.5508, val loss 2.7551
# step 7870: train loss 2.6280, val loss 2.7178
# step 7880: train loss 2.6308, val loss 2.7038
# step 7890: train loss 2.5083, val loss 2.8918
# step 7900: train loss 2.5636, val loss 2.6561
# step 7910: train loss 2.6073, val loss 2.5657
# step 7920: train loss 2.5272, val loss 2.7472
# step 7930: train loss 2.5699, val loss 2.6768
# step 7940: train loss 2.5462, val loss 2.7935
# step 7950: train loss 2.5912, val loss 2.6796
# step 7960: train loss 2.5787, val loss 2.7768
# step 7970: train loss 2.5639, val loss 2.7460
# step 7980: train loss 2.5753, val loss 2.6744
# step 7990: train loss 2.5235, val loss 2.7448
# step 8000: train loss 2.5708, val loss 2.7823
# step 8010: train loss 2.5784, val loss 2.6421
# step 8020: train loss 2.5439, val loss 2.6893
# step 8030: train loss 2.5971, val loss 2.7054
# step 8040: train loss 2.5452, val loss 2.7721
# step 8050: train loss 2.5973, val loss 2.7242
# step 8060: train loss 2.6303, val loss 2.7153
# step 8070: train loss 2.6194, val loss 2.7480
# step 8080: train loss 2.5389, val loss 2.6816
# step 8090: train loss 2.5987, val loss 2.8225
# step 8100: train loss 2.6713, val loss 2.8474
# step 8110: train loss 2.5668, val loss 2.6426
# step 8120: train loss 2.6016, val loss 2.7414
# step 8130: train loss 2.5804, val loss 2.5833
# step 8140: train loss 2.5442, val loss 2.7286
# step 8150: train loss 2.5866, val loss 2.7224
# step 8160: train loss 2.5704, val loss 2.6609
# step 8170: train loss 2.5292, val loss 2.6648
# step 8180: train loss 2.5512, val loss 2.7503
# step 8190: train loss 2.5219, val loss 2.7074
# step 8200: train loss 2.5568, val loss 2.6085
# step 8210: train loss 2.5945, val loss 2.6582
# step 8220: train loss 2.5550, val loss 2.6311
# step 8230: train loss 2.5457, val loss 2.6852
# step 8240: train loss 2.5920, val loss 2.6209
# step 8250: train loss 2.4493, val loss 2.6435
# step 8260: train loss 2.5723, val loss 2.6807
# step 8270: train loss 2.5983, val loss 2.7458
# step 8280: train loss 2.5542, val loss 2.6129
# step 8290: train loss 2.6034, val loss 2.6275
# step 8300: train loss 2.5550, val loss 2.6897
# step 8310: train loss 2.5122, val loss 2.6365
# step 8320: train loss 2.5457, val loss 2.6813
# step 8330: train loss 2.5489, val loss 2.5768
# step 8340: train loss 2.5802, val loss 2.6581
# step 8350: train loss 2.5332, val loss 2.6045
# step 8360: train loss 2.5826, val loss 2.6619
# step 8370: train loss 2.5454, val loss 2.7249
# step 8380: train loss 2.5723, val loss 2.6916
# step 8390: train loss 2.5531, val loss 2.7559
# step 8400: train loss 2.5472, val loss 2.6812
# step 8410: train loss 2.6213, val loss 2.6903
# step 8420: train loss 2.5794, val loss 2.6245
# step 8430: train loss 2.5999, val loss 2.8510
# step 8440: train loss 2.5348, val loss 2.7128
# step 8450: train loss 2.5944, val loss 2.6606
# step 8460: train loss 2.5120, val loss 2.7509
# step 8470: train loss 2.4478, val loss 2.6567
# step 8480: train loss 2.5691, val loss 2.6115
# step 8490: train loss 2.4661, val loss 2.6487
# step 8500: train loss 2.4865, val loss 2.6275
# step 8510: train loss 2.5387, val loss 2.6655
# step 8520: train loss 2.5045, val loss 2.7096
# step 8530: train loss 2.4799, val loss 2.5684
# step 8540: train loss 2.5895, val loss 2.6271
# step 8550: train loss 2.5924, val loss 2.7110
# step 8560: train loss 2.5943, val loss 2.7391
# step 8570: train loss 2.5219, val loss 2.7169
# step 8580: train loss 2.5552, val loss 2.7195
# step 8590: train loss 2.6197, val loss 2.6643
# step 8600: train loss 2.5872, val loss 2.6599
# step 8610: train loss 2.5826, val loss 2.7305
# step 8620: train loss 2.5624, val loss 2.6747
# step 8630: train loss 2.5387, val loss 2.6380
# step 8640: train loss 2.5426, val loss 2.6802
# step 8650: train loss 2.5516, val loss 2.5948
# step 8660: train loss 2.6235, val loss 2.7797
# step 8670: train loss 2.5118, val loss 2.6710
# step 8680: train loss 2.6155, val loss 2.7604
# step 8690: train loss 2.5062, val loss 2.5690
# step 8700: train loss 2.5967, val loss 2.6303
# step 8710: train loss 2.4993, val loss 2.7247
# step 8720: train loss 2.5569, val loss 2.7037
# step 8730: train loss 2.4962, val loss 2.5737
# step 8740: train loss 2.5396, val loss 2.6449
# step 8750: train loss 2.5411, val loss 2.6688
# step 8760: train loss 2.5239, val loss 2.6554
# step 8770: train loss 2.5533, val loss 2.5429
# step 8780: train loss 2.5126, val loss 2.6806
# step 8790: train loss 2.4796, val loss 2.7174
# step 8800: train loss 2.5285, val loss 2.5961
# step 8810: train loss 2.4902, val loss 2.5944
# step 8820: train loss 2.6055, val loss 2.6638
# step 8830: train loss 2.4794, val loss 2.6549
# step 8840: train loss 2.5424, val loss 2.7432
# step 8850: train loss 2.6314, val loss 2.5837
# step 8860: train loss 2.5353, val loss 2.7174
# step 8870: train loss 2.5631, val loss 2.6429
# step 8880: train loss 2.5775, val loss 2.6696
# step 8890: train loss 2.5297, val loss 2.6644
# step 8900: train loss 2.5317, val loss 2.5056
# step 8910: train loss 2.4896, val loss 2.5530
# step 8920: train loss 2.4985, val loss 2.7069
# step 8930: train loss 2.6151, val loss 2.5478
# step 8940: train loss 2.5536, val loss 2.5945
# step 8950: train loss 2.5089, val loss 2.5971
# step 8960: train loss 2.6037, val loss 2.6804
# step 8970: train loss 2.6200, val loss 2.5982
# step 8980: train loss 2.5267, val loss 2.6554
# step 8990: train loss 2.5019, val loss 2.6960
# step 9000: train loss 2.4853, val loss 2.6973
# step 9010: train loss 2.5737, val loss 2.6465
# step 9020: train loss 2.5868, val loss 2.7329
# step 9030: train loss 2.5558, val loss 2.5640
# step 9040: train loss 2.5969, val loss 2.6263
# step 9050: train loss 2.5631, val loss 2.6624
# step 9060: train loss 2.5056, val loss 2.5657
# step 9070: train loss 2.4681, val loss 2.6151
# step 9080: train loss 2.5249, val loss 2.7866
# step 9090: train loss 2.5759, val loss 2.6746
# step 9100: train loss 2.5189, val loss 2.6554
# step 9110: train loss 2.6040, val loss 2.6476
# step 9120: train loss 2.5324, val loss 2.7242
# step 9130: train loss 2.5646, val loss 2.5579
# step 9140: train loss 2.4738, val loss 2.6293
# step 9150: train loss 2.5157, val loss 2.6822
# step 9160: train loss 2.4961, val loss 2.5927
# step 9170: train loss 2.4485, val loss 2.5598
# step 9180: train loss 2.5603, val loss 2.5687
# step 9190: train loss 2.5568, val loss 2.6864
# step 9200: train loss 2.4361, val loss 2.5946
# step 9210: train loss 2.5559, val loss 2.5915
# step 9220: train loss 2.5622, val loss 2.5734
# step 9230: train loss 2.5402, val loss 2.6279
# step 9240: train loss 2.5282, val loss 2.5287
# step 9250: train loss 2.4974, val loss 2.6165
# step 9260: train loss 2.5073, val loss 2.7087
# step 9270: train loss 2.5473, val loss 2.5840
# step 9280: train loss 2.4812, val loss 2.7009
# step 9290: train loss 2.5192, val loss 2.6413
# step 9300: train loss 2.5221, val loss 2.6145
# step 9310: train loss 2.5338, val loss 2.6156
# step 9320: train loss 2.4944, val loss 2.6443
# step 9330: train loss 2.4892, val loss 2.6011
# step 9340: train loss 2.5456, val loss 2.5955
# step 9350: train loss 2.5139, val loss 2.6063
# step 9360: train loss 2.5155, val loss 2.6945
# step 9370: train loss 2.5496, val loss 2.6761
# step 9380: train loss 2.5563, val loss 2.5791
# step 9390: train loss 2.5254, val loss 2.5837
# step 9400: train loss 2.5401, val loss 2.5780
# step 9410: train loss 2.5026, val loss 2.6794
# step 9420: train loss 2.4612, val loss 2.5539
# step 9430: train loss 2.5964, val loss 2.5771
# step 9440: train loss 2.4237, val loss 2.6645
# step 9450: train loss 2.4935, val loss 2.5222
# step 9460: train loss 2.5033, val loss 2.6298
# step 9470: train loss 2.4720, val loss 2.6016
# step 9480: train loss 2.5775, val loss 2.6909
# step 9490: train loss 2.4742, val loss 2.5927
# step 9500: train loss 2.5630, val loss 2.6038
# step 9510: train loss 2.5366, val loss 2.6072
# step 9520: train loss 2.5173, val loss 2.6816
# step 9530: train loss 2.4697, val loss 2.6325
# step 9540: train loss 2.4788, val loss 2.5787
# step 9550: train loss 2.5381, val loss 2.5262
# step 9560: train loss 2.5247, val loss 2.6282
# step 9570: train loss 2.4764, val loss 2.5692
# step 9580: train loss 2.5999, val loss 2.5461
# step 9590: train loss 2.5017, val loss 2.6588
# step 9600: train loss 2.5501, val loss 2.6608
# step 9610: train loss 2.6007, val loss 2.6205
# step 9620: train loss 2.4085, val loss 2.6842
# step 9630: train loss 2.4549, val loss 2.5787
# step 9640: train loss 2.4700, val loss 2.6207
# step 9650: train loss 2.5221, val loss 2.7332
# step 9660: train loss 2.4983, val loss 2.6998
# step 9670: train loss 2.5037, val loss 2.5743
# step 9680: train loss 2.5084, val loss 2.5254
# step 9690: train loss 2.4579, val loss 2.5529
# step 9700: train loss 2.5124, val loss 2.5607
# step 9710: train loss 2.5320, val loss 2.4840
# step 9720: train loss 2.5055, val loss 2.5602
# step 9730: train loss 2.4977, val loss 2.5276
# step 9740: train loss 2.6035, val loss 2.5900
# step 9750: train loss 2.5090, val loss 2.5888
# step 9760: train loss 2.5705, val loss 2.5741
# step 9770: train loss 2.4664, val loss 2.5482
# step 9780: train loss 2.5407, val loss 2.5843
# step 9790: train loss 2.4517, val loss 2.6514
# step 9800: train loss 2.5365, val loss 2.5284
# step 9810: train loss 2.4505, val loss 2.5934
# step 9820: train loss 2.5836, val loss 2.5559
# step 9830: train loss 2.4849, val loss 2.6464
# step 9840: train loss 2.3950, val loss 2.5435
# step 9850: train loss 2.5857, val loss 2.6359
# step 9860: train loss 2.5083, val loss 2.6174
# step 9870: train loss 2.5010, val loss 2.6297
# step 9880: train loss 2.5860, val loss 2.6294
# step 9890: train loss 2.5327, val loss 2.5811
# step 9900: train loss 2.5066, val loss 2.6140
# step 9910: train loss 2.5053, val loss 2.5666
# step 9920: train loss 2.4575, val loss 2.6077
# step 9930: train loss 2.4758, val loss 2.5426
# step 9940: train loss 2.4929, val loss 2.6255
# step 9950: train loss 2.4771, val loss 2.5716
# step 9960: train loss 2.5322, val loss 2.6106
# step 9970: train loss 2.4092, val loss 2.5894
# step 9980: train loss 2.5182, val loss 2.6306
# step 9990: train loss 2.4536, val loss 2.5568

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
idx = idx.to(device)
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
#  b, gés.  cres creufur,
# LE[KÈ7WV4. ais à l pè(_0Qux-Alabâmêvolent  A cTTreuss, sqIUhasou ss, mmoreui

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = nn.Linear(C, head_size)
# define the Query layer
query = nn.Linear(C, head_size)
# define the Value layer
value = nn.Linear(C, head_size) 
# apply each layer to the input
k = key(x) # (B, T, head_size)
q = query(x) # (B, T, head_size)
v = value(x) # (B, T, head_size)
# compute the normalize product between Q and K 
weights = q @ k.transpose(2, 1)   # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = nn.functional.softmax(weights, dim=-1)
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
# tensor([[ 2.6783e-01,  7.0722e-01,  1.8232e-01, -5.6147e-02, -4.5416e-01,
#          -2.1869e-01, -7.5906e-01, -2.1618e-01,  9.8251e-02,  2.4222e-01,
#           1.9062e-01, -4.7792e-02, -1.0829e+00,  5.5875e-01, -1.0020e+00,
#          -6.4193e-01],
#         [ 1.5816e-01,  6.4898e-01,  3.9707e-01,  2.7393e-01, -1.8681e-01,
#           9.6248e-02, -3.2843e-01,  1.8845e-02, -4.7110e-01,  3.4965e-01,
#           6.1963e-02, -2.7818e-01, -7.6924e-01,  6.7636e-01, -3.6629e-01,
#          -1.1572e-01],
#         [ 1.4410e-01,  5.7408e-01,  4.9564e-01,  3.5779e-01, -1.2346e-01,
#           1.2333e-01, -2.0969e-01,  6.9935e-02, -6.2952e-01,  3.5225e-01,
#           9.9520e-02, -2.4978e-01, -5.5514e-01,  6.9397e-01, -1.3129e-01,
#           1.1630e-01],
#         [ 1.3464e-01,  1.7919e-01, -9.1036e-01, -4.1080e-01,  1.1992e-01,
#           1.1242e-01, -1.3924e+00, -3.4647e-03, -1.5799e-01, -6.3326e-01,
#          -2.6984e-01, -4.7603e-01, -1.1673e+00,  5.8155e-02, -8.8171e-02,
#           2.1511e-01],
#         [ 4.0853e-02,  1.1341e-01, -7.4566e-01, -2.3286e-01,  2.7718e-01,
#           2.3892e-01, -1.1170e+00,  1.2549e-01, -4.8144e-01, -5.9248e-01,
#          -2.8293e-01, -5.3055e-01, -8.7532e-01,  7.8947e-02,  2.9947e-01,
#           5.0963e-01],
#         [-1.1984e-01,  1.7696e-01, -7.0935e-01, -4.7575e-01,  3.3465e-01,
#           1.1209e-01, -1.0882e+00, -4.2193e-02, -2.5433e-01, -6.4377e-01,
#          -1.9778e-01, -2.8274e-01, -8.5213e-01, -6.8638e-02,  8.4122e-02,
#           2.7157e-01],
#         [ 5.9151e-02, -6.2848e-02, -1.3981e+00, -5.7349e-01,  3.7740e-01,
#           2.4559e-01, -1.6631e+00,  8.3418e-02, -2.6738e-01, -1.0383e+00,
#          -4.7089e-01, -6.5397e-01, -1.1822e+00, -1.8168e-01,  3.1689e-01,
#           6.0565e-01],
#         [-9.6686e-02,  1.5915e-01,  4.3974e-01, -1.2733e-03, -8.3700e-02,
#          -4.2586e-01, -2.4607e-01, -1.6013e-01, -3.3315e-01, -1.4461e-01,
#           5.2732e-01,  4.6461e-01,  2.6877e-01,  2.1499e-01,  4.8033e-02,
#           3.7357e-01]], grad_fn=<SelectBackward0>)

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %%
# !python gpt_single_head.py
# Out:
# 0.009989 M parameters
# step 0: train loss 4.7054, val loss 4.6731
# step 500: train loss 2.7430, val loss 2.8467
# step 1000: train loss 2.4996, val loss 2.5927
# step 1500: train loss 2.4571, val loss 2.5604
# step 2000: train loss 2.4131, val loss 2.5589
# step 2500: train loss 2.3903, val loss 2.5651
# step 3000: train loss 2.3752, val loss 2.5359
# step 3500: train loss 2.3536, val loss 2.5113
# step 4000: train loss 2.3521, val loss 2.4266
# step 4500: train loss 2.3412, val loss 2.4794
# step 4999: train loss 2.3423, val loss 2.4739
#
#  Noigrée vel!
# L'eus, u vele!
#  Sanbre, fones nori,  me  ssutomberchens  claie, faulesuse fîbleux, end qurs s on.
#   De   de que encfforeerchanc l'à luraurr.
# Sireimèrère es dommes e es hart ent d  hema, le von! her.
# Lèret ndens
#  Moné, Dantux, a t! L'e l'ux beisi tt des, bancous souret lutentes n à le  cieux,   où ache l'eu.
# Bore fan vobren preande pr leu nevracablent deulen, cosours e chire.
# Entr,
# Oni, meut   âmoure denourchatgel'ét d'es, chis, rà brtarverintotit et e c suce
# Vont Cosqu à crimmut da

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
from gpt_single_head import Head
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802

# %%
# !python gpt_multi_head.py
# Out:
# 0.009989 M parameters
# step 0: train loss 4.6782, val loss 4.6303
# step 500: train loss 2.6298, val loss 2.7236
# step 1000: train loss 2.4294, val loss 2.4543
# step 1500: train loss 2.3337, val loss 2.3388
# step 2000: train loss 2.2649, val loss 2.3058
# step 2500: train loss 2.2379, val loss 2.2896
# step 3000: train loss 2.2016, val loss 2.2742
# step 3500: train loss 2.1836, val loss 2.2441
# step 4000: train loss 2.1691, val loss 2.1747
# step 4500: train loss 2.1548, val loss 2.2099
# step 4999: train loss 2.1476, val loss 2.1939
#
#          vul!
# L'eux,  l'air!
#         crone porre, ceur cestis lez qu'étella l'hielest ec ge,
# Van paus,
# Tons de.
#
# Et tu de que feufforserchanc l'à lus pèr.
# Siré mèrère es dons serses bère en ra yhert, le vont hortel de maisss
#  l'oyaunt bux, aut! L'e voule mail tu des,
# Ton-t s'êdieut lutent arê à le ce et an foù arore!
# Peure en fonn; qui mes aiser mes péère arable pad, les, cosours et qui l'Eque,
# On soiret où pour du vourchitgells seurs dezs dr'à britre din!
#
# Et et jay sure
# Vout Corse à cen futent

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
# !python gpt_multi_head.py
# Out:
# 0.011045 M parameters
# step 0: train loss 4.5875, val loss 4.5971
# step 500: train loss 2.5660, val loss 2.5901
# step 1000: train loss 2.3709, val loss 2.3675
# step 1500: train loss 2.2941, val loss 2.3092
# step 2000: train loss 2.2485, val loss 2.2419
# step 2500: train loss 2.2140, val loss 2.2227
# step 3000: train loss 2.1781, val loss 2.2019
# step 3500: train loss 2.1533, val loss 2.1912
# step 4000: train loss 2.1352, val loss 2.1322
# step 4500: train loss 2.1198, val loss 2.1284
# step 4999: train loss 2.1081, val loss 2.1219
#
#       De vu dère je pur.
#
# L'ent chur, don!
# De hait me ces tombre le arenclail faules l'au,
# Er la pau fers s'oi.
#
# Et tu de que en foie, rarté. Il.
# Lu aux daîit-de et
# Ques gyance eves hart en rag n'or, le vant hortre dolendess
#            L'est tort cet lèveriil tu des, dant cie, hune lutre,
# Oin à le ce et l'esois chen!
# Peur que fant; qui me dande pre sontevraigble pêdeuler, copor sonché;
# Mommile,
# Oyistiret où pour d'andez quegll'étades:
# Quis drrà briarve. je ait et la cau ge vante, qui de tres, da

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
